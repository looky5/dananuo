# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %%
import numpy as np
import pandas as pd
import csv

# %%
product_data = pd.read_csv('./data/product.csv').fillna('없음')
df_product = pd.DataFrame(product_data)

# %%
product_data = pd.read_csv('./data/product.csv').fillna('없음')
df_product = pd.DataFrame(product_data)

# %%
product_name = np.array(product_data['상품명'])
product_name
# Out:
# array(['단색 일자핏팬츠 HSPA0B110G1', '박스핏 반팔 면티셔츠 FHMMCTR504M',
#        'X Mindblower 스트링 5부 쇼츠 FS2TRA2R01X INA', ...,
#        '여성 루즈핏 하찌 니트 KMD-KP721W0', 'NYY 레터링 포인트 기본 반팔 티셔츠 31TSCL831-50W',
#        '절개 라인 미디 스커트 LWSKFK0100BK26'], dtype=object)

# %%
words = []
for text in product_name:
    for word in text.split(' '):
        words.append(word)

words = set(words)

# %%
words
# Out:
# {'',
#  '706843-437',
#  'DLSH0B403O1',
#  '브라내장',
#  '자개',
#  'LSWPU560-BK',
#  'MSV2OO2032MGR',
#  'ED6FM31LS115NY',
#  '윈드스톰',
#  '(LF-194)',
#  'R172PT956',
#  '8003208',
#  'LMP09C602DE',
#  'DN5944',
#  '판테스',
#  'DKES2BSS122V1',
#  'CDCP2B1114V0',
#  'YSWBV509YSWPV510',
#  'JHPW4212',
#  '31JP15741-50L',
#  'OK8WD723',
#  'NB1931-100',
#  'ASW810146',
#  'AR4993-100',
#  '(4211JT003)',
#  'SWWJKH31020',
#  'DRCD3415',
#  'GGAA0BL37',
#  'WDCVT040M',
#  'HZTS0B909N2',
#  'L182KSK051_BK1',
#  'DE41602',
#  '1BYHPM7007',
#  '19887-0112',
#  'HPT0301605',
#  'X1NMWBM03',
#  'MARTLQS1231_53',
#  'CDHR2B12064A0',
#  'BZS4WC1201RD',
#  'SRUCZ2956',
#  'AG2DL431-DB',
#  '21162TR121_NA',
#  '미니별패턴',
#  '228465WY2R',
#  'MDS15678',
#  'T2DRZ527M_MIT',
#  '플러피',
#  '4210WT303',
#  'BGWPT493',
#  'HK자켓#1',
#  'DZ9001',
#  'M148MTJ124M1GY5',
#  'U5211LHP63',
#  '5256',
#  'DNPA9B401N2',
#  'G13FMRT902',
#  'AW763140',
#  'LWSLGL0400WI25',
#  'FMk53100',
#  'SS5F8MSP700450',
# ...

# %%
import re
codelist = [] # 제품코드 추출할 리스트
# openmarket = df_openmarket[df_openmarket['상품 코드'] == input]
# print(openmarket)
# for i in range((int)(openmarket.size/10)):
#     name = openmarket.iloc[i,2] # 상품명
# #     print(name)
p = re.compile('[a-zA-Z0-9_\s)(]+') # 정규식
#     nameLen = len(name) # 상품명 길이
    
#     # 괄호 구하기 위한 리스트
#     stack = []
#     blanklist = []
#     templist = []
    
#     blankSearch(name, nameLen, stack, blanklist, templist)
#     # 정규식 사용하여 제품코드 추출하기
#     blankLen = len(blanklist)
#     blankLen = (int)(blankLen/2)
templist = []
for k in words:
    matchname = p.match(k)
    if matchname == None:
#         resultname = matchname.group()
    
#         templist.append(df_openmarket.iloc[i,1])
        templist.append(k)
#         codelist.append(templist)
    
# print(codelist[0][1])
# if not codelist:
#     print("asd")
print(templist)
# Out:
# ['셔츠', '스트랩', '박스핏', '저중심', '무한도전', '더치로', '네이비', '런닝', '캐릭터', '니트', '심리스', '팬츠', '다잉', '슬리브리스', '메쉬', '가먼트', '브라', '싱글기본티셔츠', '긴팔', '슬림핏', '로고', '폴로', '면혼방', '솔리드', '레깅스', '캐쥬얼', '중기장', '메쉬컷팅', '디즈니픽사', '로고자수', '집업', '밀크', '모시메리', '도트', '선데이', '브라런닝팬티', '블랙', '남성', '반팔', '앙고라', '그레이', '남여공용', '기모', '쇼츠', '몰드', '컬러', '스트링', '베이직', '깅엄', '테이퍼', '방풍', '일자핏팬츠', '저지', '박스', '세미', '비비드', '와이드', '세트', '수트', '라이프스타일', '클래식핏', '정장', '투버튼', '디테일', '기본', '레이스', '프린트', '반팔티셔츠', '자수', '남녀공용', '롱', '코튼', '자수배색', '플로럴', '민소매', '변형', '배색', '카라', '화이트', '인견', '긴소매', '구스', '풀오버', '일자', '박스로고', '컬러배색', '스폰지', '크롭', '탑', '썸머화이트', '슬랙스', '단색', '티셔츠', '포인트', '보태니컬', '면티셔츠', '블라우스', '여성', '진', '스팽글', '세로', '워터멜론', '블루', '레이스팬티', '체크', '미들다운', '모100', '브라렛', '빅', '자켓', '그래픽', '언발', '백디테일', '티', '뉴블럭', '메시', '레터링', '스트라이프', '가디건', '면', '푸투라', '쿨', '브라탑', '하찌믹스', '브이넥', '단가라', '배기', '양키즈', '칼라', '빅로고', '조직변형', '핀', '레드', '기본핏', '날개사', '로그', '프론트', '라운드', '조직', '마이크', '등판', '나팔소매', '커스텀', '치키팬티', '쿨티셔츠', '벌룬'
# ...

# %%
len(templist)
# Out:
# 149

# %%
# 내부데이터의 상품명에서 상품코드 지우기
product_list = []
p = re.compile('[a-zA-Z0-9_\s)(]+')

for k in product_name:
    target = k.split(" ")
    new_str = []
    for kk in target:
        matchname = p.match(kk)
        if matchname == None:
            new_str.append(kk)
            new_str.append(" ")
    new_str = ''.join(new_str)
    product_list.append(new_str)
    print(new_str)
# Out:
# 단색 일자핏팬츠
# 박스핏 반팔 면티셔츠
# 스트링 쇼츠
# 레드 프린트 면 반팔 티셔츠
# 네이비 컬러배색 반팔 카라 티셔츠
# 남녀공용 디즈니픽사 마이크 캐릭터 티셔츠
# 남성 쿨 도트 배색 셔츠
# 플로럴 레이스 심리스 브라탑
# 벌룬 진
# 커스텀 슬림핏 코튼 티
# 스트랩 포인트 심리스 브라탑
# 저중심 스폰지 몰드 브라
# 베이직 솔리드 팬츠
# 여성 선데이 조직변형 슬리브리스
# 단색 일자핏팬츠
# 도트 슬림핏 긴소매 셔츠
# 스트랩 포인트 심리스 브라탑
# 밀크 티셔츠
# 등판 메쉬 캐쥬얼 방풍 자켓
# 빅로고 라운드 티셔츠
# 화이트 프린트 면 반팔 티셔츠
# 등판 메쉬 캐쥬얼 방풍 자켓
# 여성 하찌믹스 언발 풀오버
# 베이직 솔리드 팬츠
# 로그 스팽글 티셔츠
# 플로럴 레이스 심리스 브라탑
# 남성 모시메리 베이직 런닝
# 가먼트 다잉 티셔츠
# 레이스 치키팬티
# 메쉬 빅 로고 기본 반팔티셔츠
# 인견 여성 브라런닝팬티 세트
# 튜브 중기장 구스 미들다운
# 메쉬 빅 로고 기본 반팔티셔츠
# 프린트 캐쥬얼 방풍 자켓
# 백디테일 심리스 브라탑
# 모100 체크 정장 수트
# 화이트 스트라이프 면 반팔 티셔츠
# 워터멜론 크롭 티셔츠
# 슬리브리스 티셔츠
# 프린트 캐쥬얼 방풍 자켓
# 백디테일 심리스 브라탑
# 썸머화이트 레이스팬티 세트
# 남성 변형 조직 싱글기본티셔츠
# 모100 체크 투버튼 정장 자켓
# 남여공용 무한도전 라운드 반팔티셔츠
# 슬리브리스 티셔츠
# 남여공용 무한도전 라운드 반팔티셔츠
# 남여공용 무한도전 라운드 반팔티셔츠
# 니트 배색 민소매 탑
# 양키즈 티셔츠
# 남여공용 로고자수 브이넥 가디건
# 모100 체크 정장 팬츠
# 메쉬 빅 로고 기본 반팔티셔츠
# 로고 티셔츠
# 클래식핏 스트라이프 메시 폴로
# 단색 일자핏팬츠
# 블랙 세로 뉴블럭 반팔 티셔츠
# 메쉬 빅 로고 기본 반팔티셔츠
# 백디테일 심리스 브라탑
# 깅엄 디테일 칼라 티셔츠
# 그레이 스트라이프 면혼방 반팔 티셔츠
# ...

# %%
product_list
# Out:
# ['단색 일자핏팬츠 ',
#  '박스핏 반팔 면티셔츠 ',
#  '스트링 쇼츠 ',
#  '레드 프린트 면 반팔 티셔츠 ',
#  '네이비 컬러배색 반팔 카라 티셔츠 ',
#  '남녀공용 디즈니픽사 마이크 캐릭터 티셔츠 ',
#  '남성 쿨 도트 배색 셔츠 ',
#  '플로럴 레이스 심리스 브라탑 ',
#  '벌룬 진 ',
#  '커스텀 슬림핏 코튼 티 ',
#  '스트랩 포인트 심리스 브라탑 ',
#  '저중심 스폰지 몰드 브라 ',
#  '베이직 솔리드 팬츠 ',
#  '여성 선데이 조직변형 슬리브리스 ',
#  '단색 일자핏팬츠 ',
#  '도트 슬림핏 긴소매 셔츠 ',
#  '스트랩 포인트 심리스 브라탑 ',
#  '밀크 티셔츠 ',
#  '등판 메쉬 캐쥬얼 방풍 자켓 ',
#  '빅로고 라운드 티셔츠 ',
#  '화이트 프린트 면 반팔 티셔츠 ',
#  '등판 메쉬 캐쥬얼 방풍 자켓 ',
#  '여성 하찌믹스 언발 풀오버 ',
#  '베이직 솔리드 팬츠 ',
#  '로그 스팽글 티셔츠 ',
#  '플로럴 레이스 심리스 브라탑 ',
#  '남성 모시메리 베이직 런닝 ',
#  '가먼트 다잉 티셔츠 ',
#  '레이스 치키팬티 ',
#  '메쉬 빅 로고 기본 반팔티셔츠 ',
#  '인견 여성 브라런닝팬티 세트 ',
#  '튜브 중기장 구스 미들다운 ',
#  '메쉬 빅 로고 기본 반팔티셔츠 ',
#  '프린트 캐쥬얼 방풍 자켓 ',
#  '백디테일 심리스 브라탑 ',
#  '모100 체크 정장 수트 ',
#  '화이트 스트라이프 면 반팔 티셔츠 ',
#  '워터멜론 크롭 티셔츠 ',
#  '슬리브리스 티셔츠 ',
#  '프린트 캐쥬얼 방풍 자켓 ',
#  '백디테일 심리스 브라탑 ',
#  '썸머화이트 레이스팬티 세트 ',
#  '남성 변형 조직 싱글기본티셔츠 ',
#  '모100 체크 투버튼 정장 자켓 ',
#  '남여공용 무한도전 라운드 반팔티셔츠 ',
#  '슬리브리스 티셔츠 ',
#  '남여공용 무한도전 라운드 반팔티셔츠 ',
# ...

# %%
word2int = {}

for i,word in enumerate(templist):
    word2int[word] = i

sentences = []
for sentence in product_list:
    sentences.append(sentence.split())

WINDOW_SIZE = 2

data = []
for sentence in sentences:
    for idx, word in enumerate(sentence):
        for neighbor in sentence[max(idx - WINDOW_SIZE, 0) : min(idx + WINDOW_SIZE, len(sentence)) + 1] : 
            if neighbor != word:
                data.append([word, neighbor])

# %%
import pandas as pd
# for text in product_name:
#     print(text)

df = pd.DataFrame(data, columns = ['input', 'label'])

# %%
df.head(10)
# Out:
#    input  label
# 0     단색  일자핏팬츠
# 1  일자핏팬츠     단색
# 2    박스핏     반팔
# 3    박스핏   면티셔츠
# 4     반팔    박스핏
# 5     반팔   면티셔츠
# 6   면티셔츠    박스핏
# 7   면티셔츠     반팔
# 8    스트링     쇼츠
# 9     쇼츠    스트링

# %%
df.shape
# Out:
# (848, 2)

# %%
word2int
# Out:
# {'셔츠': 0,
#  '스트랩': 1,
#  '박스핏': 2,
#  '저중심': 3,
#  '무한도전': 4,
#  '더치로': 5,
#  '네이비': 6,
#  '런닝': 7,
#  '캐릭터': 8,
#  '니트': 9,
#  '심리스': 10,
#  '팬츠': 11,
#  '다잉': 12,
#  '슬리브리스': 13,
#  '메쉬': 14,
#  '가먼트': 15,
#  '브라': 16,
#  '싱글기본티셔츠': 17,
#  '긴팔': 18,
#  '슬림핏': 19,
#  '로고': 20,
#  '폴로': 21,
#  '면혼방': 22,
#  '솔리드': 23,
#  '레깅스': 24,
#  '캐쥬얼': 25,
#  '중기장': 26,
#  '메쉬컷팅': 27,
#  '디즈니픽사': 28,
#  '로고자수': 29,
#  '집업': 30,
#  '밀크': 31,
#  '모시메리': 32,
#  '도트': 33,
#  '선데이': 34,
#  '브라런닝팬티': 35,
#  '블랙': 36,
#  '남성': 37,
#  '반팔': 38,
#  '앙고라': 39,
#  '그레이': 40,
#  '남여공용': 41,
#  '기모': 42,
#  '쇼츠': 43,
#  '몰드': 44,
#  '컬러': 45,
#  '스트링': 46,
#  '베이직': 47,
#  '깅엄': 48,
#  '테이퍼': 49,
#  '방풍': 50,
#  '일자핏팬츠': 51,
#  '저지': 52,
#  '박스': 53,
#  '세미': 54,
#  '비비드': 55,
#  '와이드': 56,
#  '세트': 57,
#  '수트': 58,
#  '라이프스타일': 59,
#  '클래식핏': 60,
#  '정장': 61,
#  '투버튼': 62,
#  '디테일': 63,
#  '기본': 64,
#  '레이스': 65,
#  '프린트': 66,
#  '반팔티셔츠': 67,
#  '자수': 68,
#  '남녀공용': 69,
#  '롱': 70,
#  '코튼': 71,
# ...

# %%
import tensorflow as tf
import numpy as np

ONE_HOT_DIM = len(words)

# function to convert numbers to one hot vectors
def to_one_hot_encoding(data_point_index):
    one_hot_encoding = np.zeros(ONE_HOT_DIM)
    one_hot_encoding[data_point_index] = 1
    return one_hot_encoding

X = [] # input word
Y = [] # target word

for x, y in zip(df['input'], df['label']):
    X.append(to_one_hot_encoding(word2int[ x ]))
    Y.append(to_one_hot_encoding(word2int[ y ]))

# convert them to numpy arrays
X_train = np.asarray(X)
Y_train = np.asarray(Y)

# making placeholders for X_train and Y_train
x = tf.placeholder(tf.float32, shape=(None, ONE_HOT_DIM))
y_label = tf.placeholder(tf.float32, shape=(None, ONE_HOT_DIM))

# word embedding will be 2 dimension for 2d visualization
EMBEDDING_DIM = 2 

# hidden layer: which represents word vector eventually
W1 = tf.Variable(tf.random_normal([ONE_HOT_DIM, EMBEDDING_DIM]))
b1 = tf.Variable(tf.random_normal([1])) #bias
hidden_layer = tf.add(tf.matmul(x,W1), b1)

# output layer
W2 = tf.Variable(tf.random_normal([EMBEDDING_DIM, ONE_HOT_DIM]))
b2 = tf.Variable(tf.random_normal([1]))
prediction = tf.nn.softmax(tf.add( tf.matmul(hidden_layer, W2), b2))

# loss function: cross entropy
loss = tf.reduce_mean(-tf.reduce_sum(y_label * tf.log(prediction), axis=[1]))

# training operation
train_op = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init) 

iteration = 20000
for i in range(iteration):
    # input is X_train which is one hot encoded word
    # label is Y_train which is one hot encoded neighbor word
    sess.run(train_op, feed_dict={x: X_train, y_label: Y_train})
    if i % 3000 == 0:
        print('iteration '+str(i)+' loss is : ', sess.run(loss, feed_dict={x: X_train, y_label: Y_train}))
# Out:
# iteration 0 loss is :  6.838579
# iteration 3000 loss is :  4.9452477
# iteration 6000 loss is :  4.284678
# iteration 9000 loss is :  3.8714
# iteration 12000 loss is :  3.6147711
# iteration 15000 loss is :  3.4602616
# iteration 18000 loss is :  3.3551009

# %%
vectors = sess.run(W1 + b1)
print(vectors)
# Out:
# [[ 9.29107785e-01  1.18685269e+00]
#  [ 1.27761757e+00  2.24711990e+00]
#  [ 1.00122142e+00 -1.33788013e+00]
#  [ 9.42180395e-01 -3.24604362e-02]
#  [-2.02296090e+00  2.72562432e+00]
#  [ 4.44618613e-02 -1.96266755e-01]
#  [ 2.25577950e+00 -7.07211494e-01]
#  [-1.55879509e+00  4.00667250e-01]
#  [ 1.03624761e+00 -1.25624132e+00]
#  [ 2.05981135e+00  1.80758429e+00]
#  [ 1.23059011e+00  2.75766325e+00]
#  [-1.86763036e+00 -8.26428294e-01]
#  [ 1.08607399e+00 -6.82168245e-01]
#  [ 1.27334511e+00 -1.40427187e-01]
#  [ 1.99998334e-01  1.68804133e+00]
#  [ 1.77810538e+00 -5.60859919e-01]
#  [ 8.88948023e-01 -4.86715883e-02]
#  [ 4.79060113e-01  9.58624125e-01]
#  [ 2.83560443e+00 -1.54464260e-01]
#  [ 7.14811921e-01  1.00309873e+00]
#  [-1.65626064e-01  2.82669663e+00]
#  [ 1.43732643e+00 -1.44239292e-01]
#  [ 1.79396105e+00 -9.21714664e-01]
#  [-3.12754059e+00 -1.38053492e-01]
#  [-1.53618515e+00 -2.39087150e-01]
#  [ 2.04902935e+00  1.06683207e+00]
#  [ 5.11363208e-01  5.57116866e-01]
# ...

# %%
w2v_df = pd.DataFrame(vectors, columns = ['x1', 'x2'])
w2v_df['word'] = words
w2v_df = w2v_df[['word', 'x1', 'x2']]
w2v_df
# Out:
#                 word        x1        x2
# 0    JA5U4WST730_100  0.929108  1.186853
# 1     LGSLIC6100PI25  1.277618  2.247120
# 2                 셔츠  1.001221 -1.337880
# 3          LFE03B481  0.942180 -0.032460
# 4                스트랩 -2.022961  2.725624
# ..               ...       ...       ...
# 258              HBR -0.176791  0.494729
# 259               벌룬  0.295316  0.569830
# 260               바지  0.981730  0.301808
# 261               튜브  1.438842 -0.389480
# 262               브이 -0.854039  1.039545
#
# [263 rows x 3 columns]

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np

# %%
# Load Pretrained Word2Vec
embed = hub.load("https://tfhub.dev/google/Wiki-words-250-with-normalization/2")

# %%
words = ["coffee", "cafe", "football", "soccer"]
# Compute embeddings.
embeddings = embed(words)

# %%
print(embeddings.shape)
# Out:
# (4, 250)

# %%
print(embeddings[0])
# Out:
# tf.Tensor(
# [-0.02354056 -0.08136939 -0.09588724  0.04267474 -0.03513853  0.09099629
#  -0.01959137 -0.07235982 -0.04527646 -0.02064468 -0.05868183  0.05026427
#   0.08757452 -0.02868579 -0.00528093 -0.07107743 -0.00430126 -0.1111517
#  -0.0371297  -0.07397588  0.01366727  0.04489887  0.10918173 -0.00385636
#  -0.00768068 -0.12602517  0.0073157   0.0887766  -0.06376575 -0.02794223
#   0.07697963 -0.00691205 -0.05405519 -0.11509552  0.02446181 -0.01677185
#  -0.07807938 -0.05697621 -0.08125712 -0.08814868 -0.08236694 -0.08067547
#   0.0609058  -0.03083544 -0.03890334 -0.04752342  0.05156425  0.06546737
#  -0.00422008 -0.05087236  0.00757163 -0.05662974 -0.02225585  0.09144896
#   0.01537593 -0.03186006 -0.07453508 -0.09245355 -0.0335355  -0.02733024
#  -0.09283264  0.07827969  0.01312644  0.01702355  0.03512271 -0.06434979
#  -0.07367618  0.02042403 -0.09727054 -0.02774223  0.09928335  0.06212646
#   0.09546035 -0.04408428 -0.00725705 -0.00057283 -0.0287641   0.03661085
# ...

# %%
corpus = ['king is a strong man', 
          'queen is a wise woman', 
          'boy is a young man',
          'girl is a young woman',
          'prince is a young king',
          'princess is a young queen',
          'man is strong', 
          'woman is pretty',
          'prince is a boy will be king',
          'princess is a girl will be queen']

# %%
def remove_stop_words(corpus):
    stop_words = ['is', 'a', 'will', 'be']
    results = []
    for text in corpus:
        tmp = text.split(' ')
        for stop_word in stop_words:
            if stop_word in tmp:
                tmp.remove(stop_word)
        results.append(" ".join(tmp))
    
    return results

# %%
corpus = remove_stop_words(corpus)

# %%
words = []
for text in corpus:
    for word in text.split(' '):
        words.append(word)

words = set(words)

# %%
words
# Out:
# {'boy',
#  'girl',
#  'king',
#  'man',
#  'pretty',
#  'prince',
#  'princess',
#  'queen',
#  'strong',
#  'wise',
#  'woman',
#  'young'}

# %%
word2int = {}

for i,word in enumerate(words):
    word2int[word] = i

sentences = []
for sentence in corpus:
    sentences.append(sentence.split())
    
WINDOW_SIZE = 2

data = []
for sentence in sentences:
    for idx, word in enumerate(sentence):
        for neighbor in sentence[max(idx - WINDOW_SIZE, 0) : min(idx + WINDOW_SIZE, len(sentence)) + 1] : 
            if neighbor != word:
                data.append([word, neighbor])
